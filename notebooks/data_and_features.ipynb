# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
sys.path.insert(0, str(PROJECT_ROOT))

# %%
from src.data_loader import load_data

spy = load_data()

# %%
spy.head()
# Out:
#                        Date       Open       High        Low      Close  \
# 0 2010-01-04 00:00:00-05:00  84.307682  85.072953  83.662450  85.027939
# 1 2010-01-05 00:00:00-05:00  84.975403  85.290514  84.667790  85.252998
# 2 2010-01-06 00:00:00-05:00  85.170481  85.523108  85.102960  85.313034
# 3 2010-01-07 00:00:00-05:00  85.155500  85.778224  84.915414  85.673187
# 4 2010-01-08 00:00:00-05:00  85.448107  85.995806  85.275549  85.958290
#
#       Volume  Dividends  Stock Splits  Capital Gains
# 0  118944600        0.0           0.0            0.0
# 1  111579900        0.0           0.0            0.0
# 2  116074400        0.0           0.0            0.0
# 3  131091100        0.0           0.0            0.0
# 4  126402800        0.0           0.0            0.0

# %%
from src.features import add_MA, add_EMA, add_returns, add_volatility, add_distances, add_cumulated_returns, add_rsi, add_target, add_all_features

# %%
df1 = spy.copy()
df1 = add_all_features(df1)
df1 = add_target(df1)
df1
# Out:
#                           Date        Open        High         Low  \
# 0    2010-01-04 00:00:00-05:00   84.307682   85.072953   83.662450
# 1    2010-01-05 00:00:00-05:00   84.975403   85.290514   84.667790
# 2    2010-01-06 00:00:00-05:00   85.170481   85.523108   85.102960
# 3    2010-01-07 00:00:00-05:00   85.155500   85.778224   84.915414
# 4    2010-01-08 00:00:00-05:00   85.448107   85.995806   85.275549
# ...                        ...         ...         ...         ...
# 3768 2024-12-23 00:00:00-05:00  584.031655  588.390442  580.839104
# 3769 2024-12-24 00:00:00-05:00  589.141630  594.360375  588.558452
# 3770 2024-12-26 00:00:00-05:00  592.541743  595.487135  591.138241
# 3771 2024-12-27 00:00:00-05:00  590.604363  590.841628  583.903089
# 3772 2024-12-30 00:00:00-05:00  581.066391  584.871680  577.626742
#
#            Close     Volume  Dividends  Stock Splits  Capital Gains  \
# 0      85.027939  118944600        0.0           0.0            0.0
# ...

# %%
#Test of the target
ratio = df1['Trend' == 'Range'].count() / len(df1['Trend'])
# Out:
# 0.17333686721441824

# %%
#Test of the target
ratio = df1["Trend"].value_counts(normalize = True)
ratio
# Out:
# Trend
# Bull     0.475749
# Range    0.325470
# Bear     0.198781
# Name: proportion, dtype: float64

# %%
df1.drop(['Trend'], axis=1)
# Out:
#                           Date        Open        High         Low  \
# 0    2010-01-04 00:00:00-05:00   84.307682   85.072953   83.662450
# 1    2010-01-05 00:00:00-05:00   84.975403   85.290514   84.667790
# 2    2010-01-06 00:00:00-05:00   85.170481   85.523108   85.102960
# 3    2010-01-07 00:00:00-05:00   85.155500   85.778224   84.915414
# 4    2010-01-08 00:00:00-05:00   85.448107   85.995806   85.275549
# ...                        ...         ...         ...         ...
# 3768 2024-12-23 00:00:00-05:00  584.031655  588.390442  580.839104
# 3769 2024-12-24 00:00:00-05:00  589.141630  594.360375  588.558452
# 3770 2024-12-26 00:00:00-05:00  592.541743  595.487135  591.138241
# 3771 2024-12-27 00:00:00-05:00  590.604363  590.841628  583.903089
# 3772 2024-12-30 00:00:00-05:00  581.066391  584.871680  577.626742
#
#            Close     Volume  Dividends  Stock Splits  Capital Gains  \
# 0      85.027939  118944600        0.0           0.0            0.0
# ...

# %%
df1 = add_target(df1, goalreturn=(0.03, 0.015))
ratio = df1["Trend"].value_counts(normalize = True)
ratio
# Out:
# Trend
# Range    0.564007
# Bull     0.237212
# Bear     0.198781
# Name: proportion, dtype: float64
