# %%
from src.data_loader import load_data

spy = load_data()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 from src.data_loader import load_data
#       3 spy = load_data()
#
# ModuleNotFoundError: No module named 'src'

# %%
spy.head()
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2010-01-04 00:00:00-05:00  84.307720  85.072991  83.662488  85.027977
# 2010-01-05 00:00:00-05:00  84.975418  85.290529  84.667805  85.253014
# 2010-01-06 00:00:00-05:00  85.170519  85.523147  85.102998  85.313072
# 2010-01-07 00:00:00-05:00  85.155485  85.778209  84.915399  85.673172
# 2010-01-08 00:00:00-05:00  85.448107  85.995806  85.275549  85.958290
#
#                               Volume  Dividends  Stock Splits  Capital Gains
# Date
# 2010-01-04 00:00:00-05:00  118944600        0.0           0.0            0.0
# 2010-01-05 00:00:00-05:00  111579900        0.0           0.0            0.0
# 2010-01-06 00:00:00-05:00  116074400        0.0           0.0            0.0
# 2010-01-07 00:00:00-05:00  131091100        0.0           0.0            0.0
# 2010-01-08 00:00:00-05:00  126402800        0.0           0.0            0.0
